# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
#postgresql://user:password@localhost:5432/databasename
engine = sqlalchemy.create_engine('postgresql://postgres:gonoles@localhost:5432/Athletes_Career_Lifetimes')

# %%
file = "../../Data/DataSet/NFL.csv"
nfl_df = pd.read_csv(file)
nfl_df.head()
# Out:
#   sport                name first_name     last_name   birth_city birth_state  \
# 0   NFL       Isaako Aaitui     Isaako        Aaitui          NaN         NaN
# 1   NFL         Faye Abbott       Faye        Abbott    Clearport          OH
# 2   NFL        Vince Abbott      Vince        Abbott       London         NaN
# 3   NFL       Duke Abbruzzi       Duke      Abbruzzi       Warren          RI
# 4   NFL  Karim Abdul-Jabbar      Karim  Abdul-Jabbar  Los Angeles          CA
#
#   birth_country  birth_date       college      draft_team  ... draft_year  \
# 0           NaN   1/25/1987           NaN             NaN  ...        NaN
# 1           USA  1895-08-16      Syracuse             NaN  ...        NaN
# 2       England   5/31/1958    Washington             NaN  ...        NaN
# 3           USA    8/3/1917  Rhode Island             NaN  ...        NaN
# 4           USA   6/28/1974          UCLA  Miami Dolphins  ...     1996.0
#
# ...

# %%
#finding the retirement age of listed players - subtracting the end of career year with the player's birth year
nfl_df['birth_year'] = pd.DatetimeIndex(nfl_df['birth_date']).year
nfl_df.head()
# Out:
#   sport                name first_name     last_name   birth_city birth_state  \
# 0   NFL       Isaako Aaitui     Isaako        Aaitui          NaN         NaN
# 1   NFL         Faye Abbott       Faye        Abbott    Clearport          OH
# 2   NFL        Vince Abbott      Vince        Abbott       London         NaN
# 3   NFL       Duke Abbruzzi       Duke      Abbruzzi       Warren          RI
# 4   NFL  Karim Abdul-Jabbar      Karim  Abdul-Jabbar  Los Angeles          CA
#
#   birth_country  birth_date       college      draft_team  ... position  \
# 0           NaN   1/25/1987           NaN             NaN  ...       NT
# 1           USA  1895-08-16      Syracuse             NaN  ...       BB
# 2       England   5/31/1958    Washington             NaN  ...        K
# 3           USA    8/3/1917  Rhode Island             NaN  ...       HB
# 4           USA   6/28/1974          UCLA  Miami Dolphins  ...       RB
#
# ...

# %%
#create column for retirement age
nfl_df['retire_age'] = nfl_df['year_end'] - nfl_df['birth_year']
nfl_df.head()
# Out:
#   sport                name first_name     last_name   birth_city birth_state  \
# 0   NFL       Isaako Aaitui     Isaako        Aaitui          NaN         NaN
# 1   NFL         Faye Abbott       Faye        Abbott    Clearport          OH
# 2   NFL        Vince Abbott      Vince        Abbott       London         NaN
# 3   NFL       Duke Abbruzzi       Duke      Abbruzzi       Warren          RI
# 4   NFL  Karim Abdul-Jabbar      Karim  Abdul-Jabbar  Los Angeles          CA
#
#   birth_country  birth_date       college      draft_team  ...  height weight  \
# 0           NaN   1/25/1987           NaN             NaN  ...   4-Jun  315.0
# 1           USA  1895-08-16      Syracuse             NaN  ...   8-May  182.0
# 2       England   5/31/1958    Washington             NaN  ...  11-May  207.0
# 3           USA    8/3/1917  Rhode Island             NaN  ...  10-May  175.0
# 4           USA   6/28/1974          UCLA  Miami Dolphins  ...  10-May  194.0
#
# ...

# %%
#filter retirement ages for those who started career before 1970
nfl_df = nfl_df[nfl_df['year_start'] >= 1970]
nfl_df.head(30)
# Out:
#    sport                name first_name     last_name    birth_city  \
# 0    NFL       Isaako Aaitui     Isaako        Aaitui           NaN
# 4    NFL  Karim Abdul-Jabbar      Karim  Abdul-Jabbar   Los Angeles
# 5    NFL    Isa Abdul-Quddus        Isa  Abdul-Quddus           NaN
# 6    NFL      Hamza Abdullah      Hamza      Abdullah   Los Angeles
# 7    NFL     Husain Abdullah     Husain      Abdullah   Los Angeles
# 8    NFL     Khalid Abdullah     Khalid      Abdullah  Jacksonville
# 9    NFL      Rabih Abdullah      Rabih      Abdullah  Martinsville
# 10   NFL      Rahim Abdullah      Rahim      Abdullah  Jacksonville
# 15   NFL     Victor Abiamiri     Victor      Abiamiri     Baltimore
# 16   NFL        Oday Aboushi       Oday       Aboushi           NaN
# 17   NFL     Clifton Abraham    Clifton       Abraham        Dallas
# 18   NFL      Donnie Abraham     Donnie       Abraham    Orangeburg
# 19   NFL        John Abraham       John       Abraham  Timmonsville
# ...

# %%
#filter retirement ages for those who were born before 1970
nfl_df = nfl_df[nfl_df['birth_year'] >= 1970]
nfl_df.head()
# Out:
#   sport                name first_name     last_name   birth_city birth_state  \
# 0   NFL       Isaako Aaitui     Isaako        Aaitui          NaN         NaN
# 4   NFL  Karim Abdul-Jabbar      Karim  Abdul-Jabbar  Los Angeles          CA
# 5   NFL    Isa Abdul-Quddus        Isa  Abdul-Quddus          NaN         NaN
# 6   NFL      Hamza Abdullah      Hamza      Abdullah  Los Angeles          CA
# 7   NFL     Husain Abdullah     Husain      Abdullah  Los Angeles          CA
#
#   birth_country birth_date         college            draft_team  ...  height  \
# 0           NaN  1/25/1987             NaN                   NaN  ...   4-Jun
# 4           USA  6/28/1974            UCLA        Miami Dolphins  ...  10-May
# 5           NaN   8/3/1989         Fordham                   NaN  ...   1-Jun
# 6           USA  8/20/1983  Washington St.  Tampa Bay Buccaneers  ...   2-Jun
# 7           USA  7/27/1985  Washington St.                   NaN  ...  Jun-00
#
# ...

# %%
#filter retirement ages for incorrect data
nfl_df = nfl_df[nfl_df['retire_age'] >= 18]
nfl_df.head()
# Out:
#    sport                name first_name     last_name    birth_city  \
# 0    NFL       Isaako Aaitui     Isaako        Aaitui           NaN
# 4    NFL  Karim Abdul-Jabbar      Karim  Abdul-Jabbar   Los Angeles
# 8    NFL     Khalid Abdullah     Khalid      Abdullah  Jacksonville
# 9    NFL      Rabih Abdullah      Rabih      Abdullah  Martinsville
# 10   NFL      Rahim Abdullah      Rahim      Abdullah  Jacksonville
#
#    birth_state birth_country birth_date    college          draft_team  ...  \
# 0          NaN           NaN  1/25/1987        NaN                 NaN  ...
# 4           CA           USA  6/28/1974       UCLA      Miami Dolphins  ...
# 8           FL           USA   3/6/1979  Mars Hill  Cincinnati Bengals  ...
# 9           VA           USA  4/27/1975     Lehigh                 NaN  ...
# 10          FL           USA  3/22/1976    Clemson    Cleveland Browns  ...
#
#     height weight  death_date death_city death_state  death_country  \
# ...

# %%
#find career length/years played and starting age
nfl_df['years_played'] = nfl_df['year_end'] - nfl_df['year_start'] +1
nfl_df['start_age'] = nfl_df['year_start'] - nfl_df['birth_year']
nfl_df.head(30)
# Out:
#     sport                name first_name     last_name       birth_city  \
# 0     NFL       Isaako Aaitui     Isaako        Aaitui              NaN
# 4     NFL  Karim Abdul-Jabbar      Karim  Abdul-Jabbar      Los Angeles
# 8     NFL     Khalid Abdullah     Khalid      Abdullah     Jacksonville
# 9     NFL      Rabih Abdullah      Rabih      Abdullah     Martinsville
# 10    NFL      Rahim Abdullah      Rahim      Abdullah     Jacksonville
# 15    NFL     Victor Abiamiri     Victor      Abiamiri        Baltimore
# 16    NFL        Oday Aboushi       Oday       Aboushi              NaN
# 17    NFL     Clifton Abraham    Clifton       Abraham           Dallas
# 18    NFL      Donnie Abraham     Donnie       Abraham       Orangeburg
# 19    NFL        John Abraham       John       Abraham     Timmonsville
# 24    NFL        Kevin Abrams      Kevin        Abrams            Tampa
# 93    NFL         Levy Adcock       Levy        Adcock              NaN
# ...

# %%
nfl_df = nfl_df.drop(columns=['first_name', 'last_name', 'birth_year', 'birth_city', 'birth_state', 'birth_country', 'birth_date', 'college', 'draft_team', 'draft_round', 'draft_pick', 'draft_year', 'height', 'weight', 'death_date', 'death_city', 'death_state', 'death_country'])
nfl_df.head(30)
# Out:
#     sport                name position  year_start  year_end  retire_age  \
# 0     NFL       Isaako Aaitui       NT        2013      2013        26.0
# 4     NFL  Karim Abdul-Jabbar       RB        1996      2000        26.0
# 8     NFL     Khalid Abdullah       LB        1996      2000        21.0
# 9     NFL      Rabih Abdullah       RB        1996      2000        25.0
# 10    NFL      Rahim Abdullah       LB        1996      2000        24.0
# 15    NFL     Victor Abiamiri       DE        2007      2011        25.0
# 16    NFL        Oday Aboushi       OT        2013      2013        22.0
# 17    NFL     Clifton Abraham       DB        1995      1997        26.0
# 18    NFL      Donnie Abraham       DB        1995      1997        24.0
# 19    NFL        John Abraham       DE        1995      1997        19.0
# 24    NFL        Kevin Abrams       DB        1995      1997        23.0
# 93    NFL         Levy Adcock        T        2012      2012        24.0
# ...

# %%
#next -> filter down to 5 positions (rb, qb, wr, lb, OT)
position_list = ['RB', 'QB', 'WR', 'LB', 'CB']
retired_nfl_df = nfl_df[nfl_df['position'].isin(position_list)]
retired_nfl_df.head(30)
# Out:
#     sport                name position  year_start  year_end  retire_age  \
# 4     NFL  Karim Abdul-Jabbar       RB        1996      2000        26.0
# 8     NFL     Khalid Abdullah       LB        1996      2000        21.0
# 9     NFL      Rabih Abdullah       RB        1996      2000        25.0
# 10    NFL      Rahim Abdullah       LB        1996      2000        24.0
# 95    NFL        Joseph Addai       RB        2013      2013        30.0
# 102   NFL        Xavier Adibi       LB        2008      2012        28.0
# 112   NFL       Daniel Adongo       LB        2013      2013        24.0
# 133   NFL         Kamar Aiken       WR        2011      2013        24.0
# 134   NFL           Sam Aiken       WR        2011      2013        33.0
# 139   NFL       Victor Aiyewa       LB        2013      2013        26.0
# 140   NFL      Seyi Ajirotutu       WR        2010      2013        26.0
# 141   NFL         Hakim Akbar       LB        2001      2002        22.0
# ...

# %%
retired_nfl_df = retired_nfl_df.rename(columns={'name':'playerid','year_start':'start_year', 'year_end':'retire_year'})
retired_nfl_df.head()
# Out:
#    sport            playerid position  start_year  retire_year  retire_age  \
# 4    NFL  Karim Abdul-Jabbar       RB        1996         2000        26.0
# 8    NFL     Khalid Abdullah       LB        1996         2000        21.0
# 9    NFL      Rabih Abdullah       RB        1996         2000        25.0
# 10   NFL      Rahim Abdullah       LB        1996         2000        24.0
# 95   NFL        Joseph Addai       RB        2013         2013        30.0
#
#     years_played  start_age
# 4              5       22.0
# 8              5       17.0
# 9              5       21.0
# 10             5       20.0
# 95             1       30.0

# %%
retired_nfl_df['retire_age'] = retired_nfl_df['retire_age'].map("{:.0f}".format)
retired_nfl_df['start_age'] = retired_nfl_df['start_age'].map("{:.0f}".format)

# %%
starting_nfl_df = retired_nfl_df[['playerid', 'sport', 'position', 'start_year', 'start_age', 'years_played']].copy()
retiring_nfl_df = retired_nfl_df[['playerid','sport', 'position', 'retire_year', 'retire_age', 'years_played']].copy()
starting_nfl_df.head()
# Out:
#               playerid sport position  start_year start_age  years_played
# 4   Karim Abdul-Jabbar   NFL       RB        1996        22             5
# 8      Khalid Abdullah   NFL       LB        1996        17             5
# 9       Rabih Abdullah   NFL       RB        1996        21             5
# 10      Rahim Abdullah   NFL       LB        1996        20             5
# 95        Joseph Addai   NFL       RB        2013        30             1

# %%
retiring_nfl_df = retiring_nfl_df.drop_duplicates(subset=['playerid'])
starting_nfl_df = starting_nfl_df.drop_duplicates(subset=['playerid'])

# %%
retiring_nfl_df.head()
# Out:
#               playerid sport position  retire_year retire_age  years_played
# 4   Karim Abdul-Jabbar   NFL       RB         2000         26             5
# 8      Khalid Abdullah   NFL       LB         2000         21             5
# 9       Rabih Abdullah   NFL       RB         2000         25             5
# 10      Rahim Abdullah   NFL       LB         2000         24             5
# 95        Joseph Addai   NFL       RB         2013         30             1

# %%
#Code for downloading the data
#starting_nfl_df.to_csv('../../Data/Clean_Data/clean_ start_nfl.csv', index=False)
#retiring_nfl_df.to_csv('../../Data/Clean_Data/clean_ retire_nfl.csv', index=False)

# %%
starting_nfl_df['start_age'] = starting_nfl_df['start_age'].astype('int64')
retiring_nfl_df['retire_age'] = retiring_nfl_df['retire_age'].astype('int64')

# %%
retiring_nfl_df.dtypes
# Out:
# playerid        object
# sport           object
# position        object
# retire_year      int64
# retire_age       int64
# years_played     int64
# dtype: object

# %%
#use if_exists=replace parameter to replace data if table already exists

starting_nfl_df.to_sql(
    name='nfl_starting',
    con=engine,
    index=False,
    if_exists='replace'
)

retiring_nfl_df.to_sql(
    name='nfl_retiring',
    con=engine,
    index=False,
    if_exists='replace'
)
